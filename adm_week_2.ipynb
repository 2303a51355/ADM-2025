# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51355/ADM-2025/blob/main/(Ass_2)2303a51355.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.hist(df['Age'],bins=30,color='skyblue',edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('basic histogram')
# Out:
# Text(0.5, 1.0, 'basic histogram')

# %%
plt.hist(df['Age'],bins=30,color='black',edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('bar chart')
# Out:
# Text(0.5, 1.0, 'bar chart')

# %%
plt.hist(df['Age'],bins=30,color='skyblue',edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('bar plot')
# Out:
# Text(0.5, 1.0, 'bar plot')
